# %% [markdown]
# # APIs

# %% [markdown]
# **API** = application programming interface
#
# **Client** = user, information requester
#
# **Server** = provider, answers the requests from the Client
#
# **Request** = communication for data retrieval to the server
#
# **Response** = what you receive from the server
#
# **XML** / **JSON** = ways in which webpages send their information, list of dictionaries
#
# **URL** = used to communicate with APIs, it's called endpoints

# %% [markdown]
# ## .JSON() Overview

# %%
import requests
import json
import random
from scipy import stats
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import os
import gmaps
import time

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.spacexdata.com/v2/launchpads"

# %%
# Print the response to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Retrieve the data and convert it to JSON
# The .json() parses the .json text into python language (list or dictionary)
print(requests.get(url).json())
# Out:
# [{'padid': 5, 'id': 'vafb_slc_3w', 'name': 'VAFB SLC 3W', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W', 'status': 'retired', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.6440904, 'longitude': -120.5931438}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3', 'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'}, {'padid': 2, 'id': 'ccafs_slc_40', 'name': 'CCAFS SLC 40', 'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40', 'status': 'active', 'location': {'name': 'Cape Canaveral', 'region': 'Florida', 'latitude': 28.5618571, 'longitude': -80.577366}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 52, 'successful_launches': 50, 'wikipedia': 'https://en.wikipedia.org/wi
# ...

# %%
# Pretty-prints the .json() information
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "attempted_launches": 0,
#         "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 3W",
#         "id": "vafb_slc_3w",
#         "location": {
#             "latitude": 34.6440904,
#             "longitude": -120.5931438,
#             "name": "Vandenberg Air Force Base",
#             "region": "California"
#         },
#         "name": "VAFB SLC 3W",
#         "padid": 5,
#         "status": "retired",
#         "successful_launches": 0,
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3"
#     },
#     {
#         "attempted_launches": 52,
# ...

# %% [markdown]
# ## Activity 1: SpaceX

# %%
# Get the SpaceX information for Payloads
spacex_url = "https://api.spacexdata.com/v3/payloads"

# %%
# Pretty-prints the .json() information
response = requests.get(spacex_url).json()

# Indent adds the spaces on each dependency (like for loops or if conditions)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "customers": [
#             "DARPA"
#         ],
#         "manufacturer": "SSTL",
#         "nationality": "United States",
#         "norad_id": [],
#         "orbit": "LEO",
#         "orbit_params": {
#             "apoapsis_km": 500,
#             "arg_of_pericenter": null,
#             "eccentricity": null,
#             "epoch": null,
#             "inclination_deg": 39,
#             "lifespan_years": null,
#             "longitude": null,
#             "mean_anomaly": null,
#             "mean_motion": null,
#             "periapsis_km": 400,
#             "period_min": null,
#             "raan": null,
#             "reference_system": "geocentric",
#             "regime": "low-earth",
#             "semi_major_axis_km": null
#         },
#         "payload_id": "FalconSAT-2",
#         "payload_mass_kg": 20,
#         "payload_mass_lbs": 43,
#         "payload_type": "Satellite",
#         "reused": false
#     },
#     {
#         "customers": [
# ...

# %%
# Pretty-prints the .json() information
response = requests.get(spacex_url + "/RatSat").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "customers": [
#         "SpaceX"
#     ],
#     "manufacturer": "SpaceX",
#     "nationality": "United States",
#     "norad_id": [
#         33393
#     ],
#     "orbit": "LEO",
#     "orbit_params": {
#         "apoapsis_km": 623.038,
#         "arg_of_pericenter": 129.7377,
#         "eccentricity": 0.0012666,
#         "epoch": "2020-03-17T06:53:15.000Z",
#         "inclination_deg": 9.3465,
#         "lifespan_years": null,
#         "longitude": null,
#         "mean_anomaly": 230.3939,
#         "mean_motion": 14.84810661,
#         "periapsis_km": 605.325,
#         "period_min": 96.982,
#         "raan": 74.6476,
#         "reference_system": "geocentric",
#         "regime": "low-earth",
#         "semi_major_axis_km": 6992.317
#     },
#     "payload_id": "RatSat",
#     "payload_mass_kg": 165,
#     "payload_mass_lbs": 363,
#     "payload_type": "Satellite",
#     "reused": false
# }

# %%
response = requests.get(spacex_url).json()
# for para buscar los nombres de los payloads
print(json.dumps(response, indent=4, sort_keys=True))

# %% [markdown]
# ## Manipulating Responses

# %%
response = requests.get(spacex_url + "/RatSat").json()
print(response["payload_mass_kg"],"Kg")
# Out:
# 165 Kg

# %%
print(len(response["orbit_params"]))
# Out:
# 15

# %%
payload_lbs = response["payload_mass_lbs"]
print(f"The payload weights {payload_lbs} lbs")
# Out:
# The payload weights 363 lbs

# %% [markdown]
# ## Activity 2: Far Far Away

# %%
# URL for GET requests to retrieve Star Wars character data
base_url = "https://swapi.co/api/people/"

# %%
# Create a url with a specific character id
character_id = '4'
url = base_url + character_id
print(url)
# Out:
# https://swapi.co/api/people/4

# %%
# Perform a get request for this character
response_sw = requests.get(url)
print(response_sw.url)
# Out:
# https://swapi.co/api/people/4/

# %%
# Storing the JSON response within a variable
data = response.json()
# Use json.dumps to print the json stored in variable
response_sw = requests.get(url).json()
print(json.dumps(response_sw, indent=4, sort_keys=True))
# Out:
# {
#     "birth_year": "41.9BBY",
#     "created": "2014-12-10T15:18:20.704000Z",
#     "edited": "2014-12-20T21:17:50.313000Z",
#     "eye_color": "yellow",
#     "films": [
#         "https://swapi.co/api/films/2/",
#         "https://swapi.co/api/films/6/",
#         "https://swapi.co/api/films/3/",
#         "https://swapi.co/api/films/1/"
#     ],
#     "gender": "male",
#     "hair_color": "none",
#     "height": "202",
#     "homeworld": "https://swapi.co/api/planets/1/",
#     "mass": "136",
#     "name": "Darth Vader",
#     "skin_color": "white",
#     "species": [
#         "https://swapi.co/api/species/1/"
#     ],
#     "starships": [
#         "https://swapi.co/api/starships/13/"
#     ],
#     "url": "https://swapi.co/api/people/4/",
#     "vehicles": []
# }

# %%
# Print the name of the character retrieved
name = response_sw["name"]
print(response_sw["name"])
# Out:
# Darth Vader

# %%
# Print the number of films that they were in (hint: use len())
print(len(response_sw["films"]))
# Out:
# 4

# %%
# Request the starships URL found in the starships property of the
# previously retreived json, then use the response to figure out what this 
# character's first starship was

starship_url = response_sw["starships"][0]
starship = requests.get(starship_url).json()
print(json.dumps(starship, indent = 4, sort_keys = True))
# Out:
# {
#     "MGLT": "105",
#     "cargo_capacity": "150",
#     "consumables": "5 days",
#     "cost_in_credits": "unknown",
#     "created": "2014-12-12T11:21:32.991000Z",
#     "crew": "1",
#     "edited": "2014-12-22T17:35:44.549047Z",
#     "films": [
#         "https://swapi.co/api/films/1/"
#     ],
#     "hyperdrive_rating": "1.0",
#     "length": "9.2",
#     "manufacturer": "Sienar Fleet Systems",
#     "max_atmosphering_speed": "1200",
#     "model": "Twin Ion Engine Advanced x1",
#     "name": "TIE Advanced x1",
#     "passengers": "0",
#     "pilots": [
#         "https://swapi.co/api/people/4/"
#     ],
#     "starship_class": "Starfighter",
#     "url": "https://swapi.co/api/starships/13/"
# }

# %%
first_starship = starship["name"]
print(f"{name}'s first starship was the {first_starship}")
# Out:
# Darth Vader's first starship was the TIE Advanced x1

# %% [markdown]
# ## Activity 3: Number Facts

# %%
url_num = "http://numbersapi.com"
print(url_num)
# Out:
# http://numbersapi.com

# %%
user = input("Are you looking for trivia, math, year or date?: ")
# Out:
# Are you looking for trivia, math, year or date?: trivia

# %%
if user.lower() == "date":
    day = input("Choose a day: ")
    month = input("Choose a month: ")
    #answer = requests.get(url_num + "/" + month + "/" + day + "?json").json()
    answer = requests.get(f"{url_num}/{month}/{day}/{user.lower()}?json").json()
    
else:
    number = input("Choose a number (or random): ")
    #answer = requests.get(url_num + "/" + number + "/" + user + "?json").json()
    answer = requests.get(f"{url_num}/{number}/{user.lower()}?json").json()
    
#print(json.dumps(answer, indent = 4, sort_keys = True))
print(answer["text"])
# Out:
# Choose a number (or random): random
# 76 is the atomic number of osmium.

# %% [markdown]
# ## Iterative Requests

# %%
#import random

# %%
url = "http://jsonplaceholder.typicode.com/posts/"

# %%
response_json = []

# %%
indices = random.sample(list(range(1,100)), 10)
indices
# Out:
# [69, 44, 15, 55, 79, 45, 30, 60, 49, 71]

# %%
for x in range(len(indices)):
    print(f"Making request number {x} for ID {indices[x]}")
    
    # Get one of the posts
    post_response = requests.get(url + str(indices[x]))
    
    # Save post's JSON
    response_json.append(post_response.json())
# Out:
# Making request number 0 for ID 69
# Making request number 1 for ID 44
# Making request number 2 for ID 15
# Making request number 3 for ID 55
# Making request number 4 for ID 79
# Making request number 5 for ID 45
# Making request number 6 for ID 30
# Making request number 7 for ID 60
# Making request number 8 for ID 49
# Making request number 9 for ID 71

# %%
# Print the number of current posts
print(f"We have {len(response_json)} posts!")
# Out:
# We have 10 posts!

# %%
# Print the responses we have
response_json
# Out:
# [{'userId': 7,
#   'id': 69,
#   'title': 'fugiat quod pariatur odit minima',
#   'body': 'officiis error culpa consequatur modi asperiores et\ndolorum assumenda voluptas et vel qui aut vel rerum\nvoluptatum quisquam perspiciatis quia rerum consequatur totam quas\nsequi commodi repudiandae asperiores et saepe a'},
#  {'userId': 5,
#   'id': 44,
#   'title': 'optio dolor molestias sit',
#   'body': 'temporibus est consectetur dolore\net libero debitis vel velit laboriosam quia\nipsum quibusdam qui itaque fuga rem aut\nea et iure quam sed maxime ut distinctio quae'},
#  {'userId': 2,
#   'id': 15,
#   'title': 'eveniet quod temporibus',
#   'body': 'reprehenderit quos placeat\nvelit minima officia dolores impedit repudiandae molestiae nam\nvoluptas recusandae quis delectus\nofficiis harum fugiat vitae'},
#  {'userId': 6,
#   'id': 55,
#   'title': 'sit vel voluptatem et non libero',
# ...

# %% [markdown]
# ## NY Times API

# %% [markdown]
# **Always add API Keys to .gitignore** to prevent it from getting uploaded to repositories

# %%
from pprint import pprint
from config import nyt_key

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "granola"

# %%
query_url =  f"{url}api-key=" + nyt_key + "&q={query}"
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=aIGe9dRPwx9rJ3bcNKfSEMHI7yoXTNh4&q={query}'

# %%
articles = requests.get(query_url).json()
#print(articles)
articles_list = articles['response']["docs"]
print(articles_list)
# Out:
# [{'abstract': 'Metropolitan Diary: A poet asks, from a West Coast perspective, how carless New Yorkers do their food shopping.', 'web_url': 'https://cityroom.blogs.nytimes.com/2014/09/23/a-california-query/', 'snippet': 'Metropolitan Diary: A poet asks, from a West Coast perspective, how carless New Yorkers do their food shopping.', 'lead_paragraph': 'Dear Diary:', 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'A California Query', 'kicker': 'City Room', 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Poetry and Poets', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Supermarkets and Grocery Stores', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'California', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'New York City', 'rank': 4, 'major': 'N'}], 'pub_date': '2014-09-23T12:51:44+0000', 'document_type': 'article', 'news_desk': 'Metro', 'section_
# ...

# %%
for article in articles_list:
    print(article["web_url"])
# Out:
# https://cityroom.blogs.nytimes.com/2014/09/23/a-california-query/
# https://raisingtheroof.blogs.nytimes.com/2007/11/17/greece-query/
# https://www.nytimes.com/2001/02/18/books/authors-queries.html
# https://www.nytimes.com/1999/02/21/books/author-s-query.html
# https://www.nytimes.com/2018/06/26/crosswords/daily-puzzle-2018-06-27.html
# https://www.nytimes.com/1983/04/28/sports/sports-people-query-by-stepien.html
# https://pogue.blogs.nytimes.com/2008/05/15/a-self-interested-query/
# https://www.nytimes.com/1980/03/23/archives/authors-query-112143984.html
# https://www.nytimes.com/1980/05/11/archives/authors-query.html
# https://www.nytimes.com/2007/04/04/nyregion/04prostitute.html

# %% [markdown]
# ## Activity 4: Movie Loop

# %%
from config import omdb_key

url = "http://www.omdbapi.com/?apikey=" + omdb_key + "&t="
print(url)

movies = ["Aliens", "Sing", "Moana"]
# Out:
# http://www.omdbapi.com/?apikey=f923ef9&t=

# %% [markdown]
# **www.omdbapi.com/** domain
#
# **apikey="** query parameter
#
# **&** allows you to add multiple query parameters

# %%
responses = []
for movie in movies:
    print(f"Request data from OMDB API for {movie}")
    data = requests.get(url + movie).json()
    responses.append(data)
    print(f"Director(s) for {movie} are {data['Director']}")
    #print(data)
# Out:
# Request data from OMDB API for Aliens
# Director(s) for Aliens are James Cameron
# Request data from OMDB API for Sing
# Director(s) for Sing are Garth Jennings
# Request data from OMDB API for Moana
# Director(s) for Moana are Ron Clements, John Musker, Don Hall(co-director), Chris Williams(co-director)

# %% [markdown]
# # Class 2

# %% [markdown]
# ## Activity 1: Traversal Reviews .JSON()

# %%
# Load JSON
filepath = os.path.join("youtube_response.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)

# %% [markdown]
# * Retrieve the video's title
# * Retrieve the video's rating
# * Retrieve the link to the video's thumbnail
# * Retrieve the number of views this vid

# %%
print(json.dumps(json_data, indent = 4, sort_keys = True))
# Out:
# {
#     "apiVersion": "2.0",
#     "data": {
#         "items": [
#             {
#                 "accessControl": {
#                     "comment": "allowed",
#                     "commentVote": "allowed",
#                     "embed": "allowed",
#                     "list": "allowed",
#                     "rate": "allowed",
#                     "syndicate": "allowed",
#                     "videoRespond": "moderated"
#                 },
#                 "aspectRatio": "widescreen",
#                 "category": "News",
#                 "commentCount": 22,
#                 "content": {
#                     "1": "rtsp://v5.cache3.c.youtube.com/CiILENy.../0/0/0/video.3gp",
#                     "5": "http://www.youtube.com/v/hYB0mn5zh2c?f...",
#                     "6": "rtsp://v1.cache1.c.youtube.com/CiILENy.../0/0/0/video.3gp"
#                 },
#                 "description": "Google Maps API Introduction ...",
#                 "duration": 2840,
# ...

# %%
# Title
data = json_data["data"]["items"][0]

print(f"Title: {data['title']}")
print(f"Rating: {data['rating']}")
print(f"Thumbnail: {data['thumbnail']['default']}")
print(f"Views: {data['viewCount']}")
# Out:
# Title: Google Developers Day US - Maps API Introduction
# Rating: 4.63
# Thumbnail: http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg
# Views: 220101

# %% [markdown]
# ## Requests and Responses

# %% [markdown]
# ## Activity 2: Request Review

# %% [markdown]
# * Make a request to the following endpoint (<http://nyt-mongo-scraper.herokuapp.com/api/headlines>), and store the response.
#
# * JSON-ify the response.
#
# * Print the JSON representations of the first and last posts.
#
# * Print number of posts received.

# %%
url = "http://nyt-mongo-scraper.herokuapp.com/api/headlines"

# %%
nyt = requests.get(url).json()

print(json.dumps(nyt, indent = 4, sort_keys = True))
# Out:
# [
#     {
#         "__v": 0,
#         "_id": "5e745b989bb91a001555bf7d",
#         "date": "2020-03-20T05:58:48.532Z",
#         "headline": "Handling Your Child\u2019s Disappointment When Everything Is Canceled",
#         "saved": false,
#         "summary": "Schools and events are shutting down, affecting children in unexpected ways. Here\u2019s how to deal with the letdown.",
#         "url": "https://www.nytimes.com/2020/03/18/parenting/coronavirus-kids-events-cancelled.html"
#     },
#     {
#         "__v": 0,
#         "_id": "5e745b989bb91a001555bf7c",
#         "date": "2020-03-20T05:58:48.532Z",
#         "headline": "Love Is Quarantine, and Your Apartment Is the Pod",
#         "saved": false,
#         "summary": "A new project aims to turn social distancing into a dating game, taking a cue from the reality show \u201cLove Is Blind.\u201d",
#         "url": "https://www.nytimes.com/2020/03/18/style/coronavirus-love-is-quarantine.html"
#     },
#     {
# ...

# %%
print(f"The first post is: {json.dumps(nyt[0], indent = 4, sort_keys = True)}")

# Reverse index: if 0 is the first and 1 the second, then -1 is last; -2 the second last
print(f"The last post is: {json.dumps(nyt[-1], indent = 4, sort_keys = True)}")

print(f"The total number of posts received is: {len(nyt)}")
# Out:
# The first post is: {
#     "__v": 0,
#     "_id": "5e745b989bb91a001555bf7d",
#     "date": "2020-03-20T05:58:48.532Z",
#     "headline": "Handling Your Child\u2019s Disappointment When Everything Is Canceled",
#     "saved": false,
#     "summary": "Schools and events are shutting down, affecting children in unexpected ways. Here\u2019s how to deal with the letdown.",
#     "url": "https://www.nytimes.com/2020/03/18/parenting/coronavirus-kids-events-cancelled.html"
# }
# The last post is: {
#     "__v": 0,
#     "_id": "5e745b989bb91a001555bf70",
#     "date": "2020-03-20T05:58:48.528Z",
#     "headline": "G.O.P. Aid Plan Has Corporate Tax Cuts and $1,200 Checks to Taxpayers",
#     "saved": false,
#     "summary": "See more mapsSee more mapsNikkei Japan%Shanghai China%Oil W.T.I.%S&P 500 U.S.%Dow U.S.%FTSE Britain%Daily changeData delayed at least 15 minutes",
#     "url": "https://www.nytimes.comhttps://www.nytimes.com/2020/03/20/world/coronavirus-news.html"
# }
# ...

# %% [markdown]
# ## Activity 4: OpenWeather Map

# %% [markdown]
# * Save all of your "config" information—i.e., your API key; the base URL; etc.—before moving on.
#
# * Build your query URL. Check the documentation to figure out how to request temperatures in Celsius.
#
# * Make your request, and save the API response.
#
# * Retrieve the current temperature in Bujumbura from the JSON response.
#
# * Print the temperature to the console.
#
# ##### Bonus
#
# * Augment your code to report the temperature in both Fahrenheit _and_ Celsius.

# %%
from config import openweather_key

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Guatemala City"

# Build query URL
#query_url = url + "appid=" + openweather_key + "&q=" + city "&units=metric"
query_url = url + "&q=" + city + "&units=metric&appid=" + openweather_key

# %%
exow_map = requests.get(query_url).json()
print(json.dumps(ow_map, indent = 4, sort_keys = True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 14.64,
#         "lon": -90.51
#     },
#     "dt": 1584813128,
#     "id": 3598132,
#     "main": {
#         "feels_like": 19.87,
#         "humidity": 50,
#         "pressure": 1025,
#         "temp": 24,
#         "temp_max": 24,
#         "temp_min": 24
#     },
#     "name": "Guatemala City",
#     "sys": {
#         "country": "GT",
#         "id": 7079,
#         "sunrise": 1584792302,
#         "sunset": 1584835978,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 7.2
#     }
# }

# %%
temp = url + "&q=Bujumbura&units=metric&appid=" + openweather_key
temp_f = url + "&q=Bujumbura&units=imperial&appid=" + openweather_key

# %%
ow_map_2 = requests.get(temp).json()
ow_map_3 = requests.get(temp_f).json()
print(f"The current temperature in Bujumbura is: {ow_map_2['main']['temp']}°C or {ow_map_3['main']['temp']}°F")
# Out:
# The current temperature in Bujumbura is: 15.58°C or 60.04°F

# %% [markdown]
# ## Activity 5: OpenWeather Data Frame

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={openweather_key}&units={units}&q="

# %%
cities = ["Paris", "London", "Oslo", "Beijing", "Guatemala City"]

# set up lists to hold reponse info
lat = []
temp = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [48.85, 51.51, 59.91, 39.91, 14.64]
# The temperature information received is: [7.71, 6.46, 1.51, 7.49, 24]

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#              city    lat   temp
# 0           Paris  48.85   7.71
# 1          London  51.51   6.46
# 2            Oslo  59.91   1.51
# 3         Beijing  39.91   7.49
# 4  Guatemala City  14.64  24.00

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Activity 6: TV Ratings

# %% [markdown]
# * You may use the list of TV shows provided in the starter file or create your own.
#
# * Request information on each TV show from the [TVmaze API's Show Search endpoint](https://www.tvmaze.com/api#show-search)
# * Store the name and rating information into lists.
#
# * Store this data in a dictionary and use it to create a Pandas DataFrame.
#
# * Use pandas to create a bar chart comparing the ratings of each show.

# %%
tv_shows = ["Breaking Bad", "Malcolm in the Middle", "This is Us", "The Flash", "Vikings", "Shameless", "Arrow", "Peaky Blinders", "Dirk Gently"]
shows_list = []

# Iterative requests
for show in tv_shows:
    request = requests.get("http://api.tvmaze.com/singlesearch/shows?q=" + show).json()
    rating = request["rating"]["average"]
    shows_list.append(rating)
    #print(json.dumps(request, indent = 4, sort_keys = True))

show_rating_df = pd.DataFrame({"TV Show": tv_shows,
                               "Rating": shows_list})
show_rating_df.head()
# Out:
#                  TV Show  Rating
# 0           Breaking Bad     9.3
# 1  Malcolm in the Middle     7.7
# 2             This is Us     8.1
# 3              The Flash     7.9
# 4                Vikings     8.7

# %%
show_rating_df.plot("TV Show", "Rating", kind = "bar", figsize = (10,5), title = "TV Show Ratings", rot = "30", color = "red", alpha = 0.5)
plt.show()

# %% [markdown]
# ## Activity 7: Weather Statistics

# %% [markdown]
# * Using the starter file as a guide complete the following:
#
#   * Create a scatter plot of Temperature vs. Latitude.
#
#   * Perform linear regression.
#
#   * Create a line equation for the regression.
#
#   * Create a scatter plot with the linear regression line.
#
#   * Predict the temperature of Florence at latitude 43.77&deg;.
#
#   * Use the API to determine the actual temperature of Florence.
#
# * If you finish early feel free to try to predict the temperatures of other cities.

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={openweather_key}&units={units}&q="

# %%
# Get latitude and temperature for cities
cities = ["Paris", "London", "Oslo", "Beijing", "Mumbai", "Manila", "New York", "Seattle", "Dallas", "Taipei"]

# set up lists to hold reponse info
lat = []
temp = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [48.85, 51.51, 59.91, 39.91, 19.01, 14.6, 40.71, 47.61, 32.77, 25.05]
# The temperature information received is: [7.66, 5.72, -0.34, 7.54, 26, 27.66, 9.72, 7.79, 11.8, 21.51]

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": cities,
    "Lat": lat,
    "Temp": temp
}
weather_data_df = pd.DataFrame(weather_dict)
weather_data_df
# Out:
#        City    Lat   Temp
# 0     Paris  48.85   7.66
# 1    London  51.51   5.72
# 2      Oslo  59.91  -0.34
# 3   Beijing  39.91   7.54
# 4    Mumbai  19.01  26.00
# 5    Manila  14.60  27.66
# 6  New York  40.71   9.72
# 7   Seattle  47.61   7.79
# 8    Dallas  32.77  11.80
# 9    Taipei  25.05  21.51

# %%
# T° vs Latitude Scatter Plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Temp"])

# Add title, x and y labels
plt.title("T° vs Latitude")
plt.ylabel("Temperature")
plt.xlabel("Latitude")

# Add a colorbar based on the set color
#clb = plt.colorbar()

# Add a label to the color bar
#clb.set_label("Median Income")

plt.show()

# %%
# T° vs Latitude Linear Regression
x_values = weather_data_df["Lat"]
y_values = weather_data_df["Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

plt.annotate(line_eq, (20, 25), fontsize = 15, color = "green")

plt.xlabel("Latitude")
plt.ylabel("Temperature °C")

print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: -0.9718760285752437

# %% [markdown]
# ## Exception Handling

# %%
students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

# print(students["Jezebel"])
# returns a KeyError

# We do an exception for that error
try:
    #students["Jezebel"] # KeyError
    print(1/0) # ZeroDivisionError
except:
    print("Oupsi, that key doesn't exist...")

print("... we'll still run your code though!")
# Out:
# Oupsi, that key doesn't exist...
# ... we'll still run your code though!

# %% [markdown]
# ## Activity 8: Making Exceptions

# %% [markdown]
# * Without removing any of the lines from the starter code provided, create `try` and `except` blocks that will allow the application to run without terminating.
#
# * Each `except` block should handle the specific error that will occur.
#
# * Add a `print` statement under the `except` block to log the error.

# %%
try:
    print("Infinity looks like + " + str(10 / 0) + ".")
except ZeroDivisionError:
    print("This is a ZeroDivisionError")
    
#try:
    #print("I think her name was + " + name + "?")

    #print("Your name is a nonsense number. Look: " + int("Gabriel"))

    #print("You made it through the gauntlet--the message survived!")
# Out:
# This is a ZeroDivisionError

# %% [markdown]
# ## World Bank API

# %%
url = "http://api.worldbank.org/v2/"
api_format = "json"

print(f"{url}countriesformats?")

# Get country information in JSON format
countries_response = requests.get(f"{url}countries?format={api_format}").json()

# First element is general information, second is countries themselves
countries = countries_response[1]
# Out:
# http://api.worldbank.org/v2/countriesformats?

# %%
# Report the names
for country in countries:
    print(json.dumps(country, indent = 4, sort_keys = True))
# Out:
# {
#     "adminregion": {
#         "id": "",
#         "iso2code": "",
#         "value": ""
#     },
#     "capitalCity": "Oranjestad",
#     "id": "ABW",
#     "incomeLevel": {
#         "id": "HIC",
#         "iso2code": "XD",
#         "value": "High income"
#     },
#     "iso2Code": "AW",
#     "latitude": "12.5167",
#     "lendingType": {
#         "id": "LNX",
#         "iso2code": "XX",
#         "value": "Not classified"
#     },
#     "longitude": "-70.0167",
#     "name": "Aruba",
#     "region": {
#         "id": "LCN",
#         "iso2code": "ZJ",
#         "value": "Latin America & Caribbean "
#     }
# }
# {
#     "adminregion": {
#         "id": "SAS",
#         "iso2code": "8S",
#         "value": "South Asia"
#     },
#     "capitalCity": "Kabul",
#     "id": "AFG",
#     "incomeLevel": {
#         "id": "LIC",
#         "iso2code": "XM",
#         "value": "Low income"
#     },
#     "iso2Code": "AF",
#     "latitude": "34.5228",
#     "lendingType": {
# ...

# %% [markdown]
# ## Activity 12: Lending Types

# %% [markdown]
# * Retrieve a list of the lending types the world bank keeps track of, and extract the ID key from each of them.
#
# * Next, determine how many countries are categorized under each lending type. Use a dict to store this information.
#
#   * This data is stored as the first element of the response array.
#
# * Finally, print the number of countries of each lending type.

# %%
name = []
lending = []

for country in countries:
    
    lend_type = country['lendingType']["id"]
    
    name.append(country['name'])
    lending.append(country['lendingType']["id"])

bank_df = pd.DataFrame({"Country": name,
                        "Lending Type": lending})

bank_df.head(10)
# Out:
#                 Country Lending Type
# 0                 Aruba          LNX
# 1           Afghanistan          IDX
# 2                Africa
# 3                Angola          IBD
# 4               Albania          IBD
# 5               Andorra          LNX
# 6         Andean Region
# 7            Arab World
# 8  United Arab Emirates          LNX
# 9             Argentina          IBD

# %%
lending_type = bank_df.groupby(["Lending Type"]).count()
lending_type.rename({"":"No Lending"})
# Out:
#               Country
# Lending Type
# No Lending         13
# IBD                15
# IDX                 7
# LNX                15

# %% [markdown]
# # Class 3

# %% [markdown]
# ## Activity 1: Google Drills

# %%
from config import gkey
gkey
# Out:
# 'AIzaSyDqygAwfPe3mO9LVIX9Y-lN8jdB4d_Q3ak'

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = "Seattle, Washington"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of Seattle, WA")

# Run request
seattle_geo = requests.get(base_url, params=params).json()
#print(seattle_geo)

# Extract lat/lng
lat = seattle_geo["results"][0]["geometry"]["location"]["lat"]
lng = seattle_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of Seattle, WA
# Seattle, Washington: 47.6062095, -122.3320708

# %% [markdown]
# ## Activity 2: Airport Ratings

# %%
cities_pd = pd.read_csv("cities.csv")
cities_pd.head()
# Out:
#             City         State
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania

# %%
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#             City         State Lat Lng Airport Name Airport Address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    city = row['City']
    state = row['State']

    # update address key value
    params['address'] = f"{city},{state}"

    # make request
    cities_lat_lng = requests.get(base_url, params=params)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    # print(cities_lat_lng.url)
    
    # convert to json
    cities_lat_lng = cities_lat_lng.json()

    cities_pd.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    cities_pd.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
#             City         State      Lat      Lng Airport Name Airport Address  \
# 0  New York City      New York  40.7128  -74.006
# 1    Los Angeles    California  34.0522 -118.244
# 2        Chicago      Illinois  41.8781 -87.6298
# 3        Houston         Texas  29.7604 -95.3698
# 4   Philadelphia  Pennsylvania  39.9526 -75.1652
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "airport",
    "keyword": "international airport",
    "key": gkey
}

# Use the lat/lng we recovered to identify airports
for index, row in cities_pd.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
    # print the name_address url, avoid doing for public github repos in order to avoid exposing key
    print(name_address.url)

    # convert to json
    name_address = name_address.json()
    print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_pd.loc[index, "Airport Name"] = name_address["results"][0]["name"]
        cities_pd.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        cities_pd.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyDqygAwfPe3mO9LVIX9Y-lN8jdB4d_Q3ak&location=40.7127753%2C-74.0059728
# {
#     "html_attributions": [],
#     "next_page_token": "CsQCMwEAAAcr0d_Yc-YC7x_p9R1t1hiYSm-vqC3v5hubEa0pLih6vF2POw-z68Wk9raujxgsxROu5KaqSkjSPHXr947DzSZwuLguGIEGOWy3QhaCAVNAQjXykvz2LqEElpMJXcTAYWHIJfvnlZM78FPa9lYZMAsg7d1_PXSdUUMhQW26WIo2FuJJU_mCF27J6JJ2H1R3dq7vXn-KPNu6_dyhf71TK-Vpwk6fnPRAQqiI4lrVngh3O81GAP7-M6ZchRhkHQyPYPomWh-CoOSzBCZek3PUvXnO_Eqh97HoLhJV9TUYPDDukREvlMRTdw_HUZvXWN67Gp8KPiInJL0AT2yjTuz69H1CNtWooWvZ2P_i_oSnTm6T-5Wddu9AoLHhhBFRFjrPEyNBw97ZSXdO75Hr80woJFnnPLxOZNfljDfsqC1xrPuREhAywrrX_lZwRqgsrdrWhLmUGhS-V5aO4hpGYOGsDdDNhHSIHOobpg",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6413111,
#                     "lng": -73.77813909999999
#                 },
#                 "viewport": {
# ...

# %%
# Save Data to csv
cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
cities_pd.head(10)
# Out:
#             City         State      Lat      Lng  \
# 0  New York City      New York  40.7128  -74.006
# 1    Los Angeles    California  34.0522 -118.244
# 2        Chicago      Illinois  41.8781 -87.6298
# 3        Houston         Texas  29.7604 -95.3698
# 4   Philadelphia  Pennsylvania  39.9526 -75.1652
# 5        Phoenix       Arizona  33.4484 -112.074
# 6    San Antonio         Texas  29.4241 -98.4936
# 7      San Diego    California  32.7157 -117.161
# 8         Dallas         Texas  32.7767  -96.797
# 9       San Jose    California  37.3382 -121.886
#
#                               Airport Name                   Airport Address  \
# 0    John F. Kennedy International Airport                            Queens
# 1        Los Angeles International Airport          1 World Way, Los Angeles
# 2
# 3     George Bush Intercontinental Airport       2800 N Terminal Rd, Houston
# 4       Philadelphia International Airport  8000 Essington Ave, Philadelphia
# 5
# ...

# %% [markdown]
# ## Activity 3: GMaps

# %%
gmaps.configure(api_key=gkey)

# %%
# Create a list of coordinates
coordinates = [
    (40.71, -74.00),
    (30.26, -97.74),
    (46.87, -96.78),
    (47.60, -122.33),
    (32.71, -117.16)
]

# %%
# Figure size customization
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# # Activity 4: Airport Heatmaps

# %%
# Create aiport dataframe
airport_df = pd.read_csv('Airport_Output.csv')
airport_df.dropna(inplace = True)
airport_df.head()
# Out:
#    Unnamed: 0           City         State        Lat         Lng  \
# 0           0  New York City      New York  40.712775  -74.005973
# 1           1    Los Angeles    California  34.052234 -118.243685
# 3           3        Houston         Texas  29.760427  -95.369803
# 4           4   Philadelphia  Pennsylvania  39.952584  -75.165222
# 6           6    San Antonio         Texas  29.424122  -98.493628
#
#                             Airport Name                   Airport Address  \
# 0  John F. Kennedy International Airport                            Queens
# 1      Los Angeles International Airport          1 World Way, Los Angeles
# 3   George Bush Intercontinental Airport       2800 N Terminal Rd, Houston
# 4     Philadelphia International Airport  8000 Essington Ave, Philadelphia
# 6      San Antonio International Airport    9800 Airport Blvd, San Antonio
#
#    Airport Rating
# 0             3.7
# 1             3.5
# 3             3.8
# 4             3.4
# 6             4.1

# %%
# Store latitude and longitude in locations
locations = airport_df[["Lat", "Lng"]]

# Fill NaN values and convert to float
rating = airport_df["Airport Rating"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# BONUS
# Plost as a Hybrid map
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot as a Terrain map
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Census API

# %%
from census import Census

# Census API Key
from config import census_key
c = Census(census_key, year=2013)

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate"]]

# Visualize
print(len(census_pd))
census_pd.head()
# Out:
# 33120
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   08518      5217.0        41.5           74286.0            33963.0
# 1   08520     27468.0        37.4           90293.0            37175.0
# 2   08525      4782.0        47.1          118656.0            59848.0
# 3   08527     54867.0        42.2           88588.0            37021.0
# 4   08528       245.0        48.5           58676.0            49117.0
#
#    Poverty Count  Poverty Rate
# 0          170.0      3.258578
# 1         1834.0      6.676860
# 2           43.0      0.899205
# 3         2191.0      3.993293
# 4            0.0      0.000000

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd.to_csv("census_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Activity 5: Banking Deserts Heatmap

# %%
from us import states

c = Census(census_key, year=2013)

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
census_data = c.acs5.get(("B01003_001E", "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B17001_002E": "Poverty Count",
                                      "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = census_pd["Poverty Count"].astype(int)/census_pd["Population"].astype(int) * 100

# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Poverty Rate"]]

# Visualize
print(len(census_pd))
census_pd.head()
# Out:
# 33120
#   Zipcode  Population  Poverty Rate
# 0   01832     22121.0     10.903666
# 1   01833      8295.0      2.302592
# 2   01834      6675.0      2.187266
# 3   01835     13527.0      8.523693
# 4   01840      4547.0     39.542556

# %%
# Import the original data we analyzed earlier. Use dtype="object" to match other
census_original = pd.read_csv("zip_bank_data.csv", dtype = "object", encoding = "utf-8")

census_original.head()
# Out:
#   Zipcode                      Address Median Age Household Income  \
# 0     624      Hastings, MI 49058, USA       40.8            46777
# 1     692          Ball, LA 71405, USA       35.8            55242
# 2     730   Great Mills, MD 20634, USA       31.9            79944
# 3     757  Williamsport, TN 38487, USA       41.6            38125
# 4     957        Marion, ND 58466, USA       44.5            69844
#
#   Per Capita Income         Lat          Lng Bank Count
# 0             22137  42.6306916  -85.2929384          9
# 1             23941  31.4061799   -92.396174         12
# 2             35961  38.2201614  -76.4967919          9
# 3             18884  35.7310368  -87.2419299          0
# 4             36981  46.5594224  -98.3481542          1

# %%
# Merge the two data sets along zip code
census_df = pd.merge(census_original, census_pd, how="left", on = ["Zipcode", "Zipcode"])

# Remove rows missing data
census_df = census_df.dropna()

# Visualize
census_df.head()
# Out:
#    Zipcode                    Address Median Age Household Income  \
# 63   10007    Flatonia, TX 78941, USA       45.7            40304
# 64   10303      Nevada, IA 50201, USA       40.4            56619
# 65   10309  Lukachukai, AZ 86507, USA       24.1            22009
# 66   10553   Lone Pine, CA 93545, USA       40.6            32473
# 67   10803     Niagara, WI 54151, USA       45.7            45813
#
#    Per Capita Income         Lat           Lng Bank Count  Population  \
# 63             23115  29.7574106   -97.1574784          0      6525.0
# 64             28908   42.065743   -93.4599326          7     24537.0
# 65              8346  36.4106866  -109.2593642          0     32646.0
# 66             18444  36.5131184  -118.0888578          0      9895.0
# 67             23500   45.715354   -87.9804239          2     12439.0
#
#     Poverty Rate
# 63      2.206897
# 64     21.828259
# 65      6.766526
# 66     15.260232
# 67      3.006673

# %%
# Variable to store Latitude and Longitude
locations = census_df[["Lat", "Lng"]].astype(float)

# Variable to store Poverty Rate as Float
poverty_rate = census_df["Poverty Rate"].astype(float)

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=poverty_rate, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Convert bank rate to list
bank_rate = census_df["Bank Count"].tolist()

# %%
# Create a bank symbol layer
bank_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=[f"Bank amount: {bank}" for bank in bank_rate]
)


fig = gmaps.figure()
fig.add_layer(bank_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a combined map
fig = gmaps.figure()

fig.add_layer(heat_layer)
fig.add_layer(bank_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Statistical Analysis

# %% [markdown]
# #### Summary Statistics

# %%
# Mean, median, mode for Poverty Rate
poverty_mean = round(census_df['Poverty Rate'].astype('float').mean(), 2)
poverty_median = round(census_df['Poverty Rate'].astype('float').median(), 2)
poverty_mode = round(census_df['Poverty Rate'].astype('float').mode(), 2)

print(f"Poverty Rate Mean: {poverty_mean}")
print(f"Poverty Rate Median {poverty_median}")
print(f"Poverty Rate mode {poverty_mode}")
# Out:
# Poverty Rate Mean: 14.62
# Poverty Rate Median 12.49
# Poverty Rate mode 0    0.0
# dtype: float64

# %%
# Mean, median, mode for Bank Count
bank_mean = round(census_df['Bank Count'].astype('float').mean(), 2)
bank_median = round(census_df['Bank Count'].astype('float').median(), 2)
bank_mode = round(census_df['Bank Count'].astype('float').mode(), 2)

print(f"Bank Count Mean: {bank_mean}")
print(f"Bank Count Median {bank_median}")
print(f"Bank Count mode {bank_mode}")

# %%
# Mean, median, mode for Population
population_mean = round(census_df['Population'].astype('float').mean(), 2)
population_median = round(census_df['Population'].astype('float').median(), 2)
population_mode = round(census_df['Population'].astype('float').mode(), 2)

print(f"Population Mean: {population_mean}")
print(f"Population Median {population_median}")
print(f"Population mode {population_mode}")
# Out:
# Population Mean: 10115.99
# Population Median 2971.0
# Population mode 0    337.0
# dtype: float64

# %%
#### Linear Regression

# %%
# Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = census_df['Poverty Rate'].astype('float')
y_values = census_df['Bank Count'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, alpha = 0.5)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,19),fontsize=15,color="green")

# Label plot
plt.xlabel('Poverty Rate')
plt.ylabel('Bank Count')

# Print r square value
print(f"R squared: {rvalue}")

# Show plot
plt.show()
# Out:
# R squard: 0.073905278513385

# %% [markdown]
# ### Analysis
# * There is a very weak correlation between poverty rates and bank counts. Keep in mind that linear regression will not consider other factors such as population or size of the city.
